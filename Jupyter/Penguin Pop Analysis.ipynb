# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import seaborn as sns
import matplotlib.pyplot as plt

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.dropna(axis=0)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# Group by species, island or both?
#
# compare body mass between males and females
#
# which island has the heaviest penguins? Or the most?
#
# etc.

# %%
# Creating datasets of male and female penguins
male = penguins[penguins['sex'] == 'Male']
female = penguins[penguins['sex'] == 'Female']

# %%
male
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 13   Adelie  Torgersen            38.6           21.2              191.0
# 14   Adelie  Torgersen            34.6           21.1              198.0
# ..      ...        ...             ...            ...                ...
# 333  Gentoo     Biscoe            51.5           16.3              230.0
# 335  Gentoo     Biscoe            55.1           16.0              230.0
# 337  Gentoo     Biscoe            48.8           16.2              222.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g   sex
# 0         3750.0  Male
# 5         3650.0  Male
# ...

# %%
female
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# 12   Adelie  Torgersen            41.1           17.6              182.0
# ..      ...        ...             ...            ...                ...
# 332  Gentoo     Biscoe            43.5           15.2              213.0
# 334  Gentoo     Biscoe            46.2           14.1              217.0
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
#
#      body_mass_g     sex
# 1         3800.0  Female
# 2         3250.0  Female
# ...

# %%
# Grouping on island, followed by species, males
male_grouping = male.groupby(['island', 'species']).mean()
male_grouping.head()
# Out:
#                      bill_length_mm  bill_depth_mm  flipper_length_mm  \
# island    species
# Biscoe    Adelie          40.590909      19.036364         190.409091
#           Gentoo          49.473770      15.718033         221.540984
# Dream     Adelie          40.071429      18.839286         191.928571
#           Chinstrap       51.094118      19.252941         199.911765
# Torgersen Adelie          40.586957      19.391304         194.913043
#
#                      body_mass_g
# island    species
# Biscoe    Adelie     4050.000000
#           Gentoo     5484.836066
# Dream     Adelie     4045.535714
#           Chinstrap  3938.970588
# Torgersen Adelie     4034.782609

# %%
# Grouping on island, followed by species, females
female_grouping = female.groupby(['island', 'species']).mean()
female_grouping.head()
# Out:
#                      bill_length_mm  bill_depth_mm  flipper_length_mm  \
# island    species
# Biscoe    Adelie          37.359091      17.704545         187.181818
#           Gentoo          45.563793      14.237931         212.706897
# Dream     Adelie          36.911111      17.618519         187.851852
#           Chinstrap       46.573529      17.588235         191.735294
# Torgersen Adelie          37.554167      17.550000         188.291667
#
#                      body_mass_g
# island    species
# Biscoe    Adelie     3369.318182
#           Gentoo     4679.741379
# Dream     Adelie     3344.444444
#           Chinstrap  3527.205882
# Torgersen Adelie     3395.833333

# %%
f_island_pops = female.groupby('island')['sex'].count()
# 80 females on Biscoe
# 61 females on Dream
# 24 females on Torgensen
f_island_pops
# Out:
# island
# Biscoe       80
# Dream        61
# Torgersen    24
# Name: sex, dtype: int64

# %%
m_island_pops = male.groupby('island')['sex'].count()
# 83 males on Biscoe
# 62 males on Dream
# 23 males on Torgensen
m_island_pops
# Out:
# island
# Biscoe       83
# Dream        62
# Torgersen    23
# Name: sex, dtype: int64

# %%
total_pops = pd.merge(f_island_pops, m_island_pops, how='inner', right_index=True, left_index=True)
total_pops
# Out:
#            sex_x  sex_y
# island
# Biscoe        80     83
# Dream         61     62
# Torgersen     24     23

# %%
total_pops['island_pop'] = total_pops['sex_x'] + total_pops['sex_y']
total_pops
# Out:
#            sex_x  sex_y  island_pop
# island
# Biscoe        80     83         163
# Dream         61     62         123
# Torgersen     24     23          47

# %%
total_pops["female_pop_percentage"] = (total_pops["sex_x"]/total_pops["island_pop"])*100
total_pops["males_pop_percentage"] = (total_pops["sex_y"]/total_pops["island_pop"])*100
total_pops
# Out:
#            sex_x  sex_y  island_pop  female_pop_percentage  \
# island
# Biscoe        80     83         163              49.079755
# Dream         61     62         123              49.593496
# Torgersen     24     23          47              51.063830
#
#            males_pop_percentage
# island
# Biscoe                50.920245
# Dream                 50.406504
# Torgersen             48.936170

# %%
frames = [male_grouping, female_grouping]
frames
# Out:
# [                     bill_length_mm  bill_depth_mm  flipper_length_mm  \
#  island    species
#  Biscoe    Adelie          40.590909      19.036364         190.409091
#            Gentoo          49.473770      15.718033         221.540984
#  Dream     Adelie          40.071429      18.839286         191.928571
#            Chinstrap       51.094118      19.252941         199.911765
#  Torgersen Adelie          40.586957      19.391304         194.913043
#
#                       body_mass_g
#  island    species
#  Biscoe    Adelie     4050.000000
#            Gentoo     5484.836066
#  Dream     Adelie     4045.535714
#            Chinstrap  3938.970588
#  Torgersen Adelie     4034.782609  ,
#                       bill_length_mm  bill_depth_mm  flipper_length_mm  \
#  island    species
#  Biscoe    Adelie          37.359091      17.704545         187.181818
#            Gentoo          45.563793      14.237931         212.706897
# ...

# %%
result = pd.concat(frames, keys = ['Male', 'Female'])
result
# Out:
#                             bill_length_mm  bill_depth_mm  flipper_length_mm  \
#        island    species
# Male   Biscoe    Adelie          40.590909      19.036364         190.409091
#                  Gentoo          49.473770      15.718033         221.540984
#        Dream     Adelie          40.071429      18.839286         191.928571
#                  Chinstrap       51.094118      19.252941         199.911765
#        Torgersen Adelie          40.586957      19.391304         194.913043
# Female Biscoe    Adelie          37.359091      17.704545         187.181818
#                  Gentoo          45.563793      14.237931         212.706897
#        Dream     Adelie          36.911111      17.618519         187.851852
#                  Chinstrap       46.573529      17.588235         191.735294
#        Torgersen Adelie          37.554167      17.550000         188.291667
#
#                             body_mass_g
#        island    species
# ...

# %%
result.loc['Female']
# Out:
#                      bill_length_mm  bill_depth_mm  flipper_length_mm  \
# island    species
# Biscoe    Adelie          37.359091      17.704545         187.181818
#           Gentoo          45.563793      14.237931         212.706897
# Dream     Adelie          36.911111      17.618519         187.851852
#           Chinstrap       46.573529      17.588235         191.735294
# Torgersen Adelie          37.554167      17.550000         188.291667
#
#                      body_mass_g
# island    species
# Biscoe    Adelie     3369.318182
#           Gentoo     4679.741379
# Dream     Adelie     3344.444444
#           Chinstrap  3527.205882
# Torgersen Adelie     3395.833333

# %%
# get one of those shadow type graphs comparing the body masses of males and females

# %%
result.loc['Male', 'Biscoe']
# Out:
#          bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# species
# Adelie        40.590909      19.036364         190.409091  4050.000000
# Gentoo        49.473770      15.718033         221.540984  5484.836066

# %%
result.loc['Male', 'Biscoe', 'Adelie']['bill_length_mm']
# Out:
# 40.5909090909091

# %%
# Is it possible to have a stakced bar chart for species, comparing islands?

# %%
result.index
# Out:
# MultiIndex([(  'Male',    'Biscoe',    'Adelie'),
#             (  'Male',    'Biscoe',    'Gentoo'),
#             (  'Male',     'Dream',    'Adelie'),
#             (  'Male',     'Dream', 'Chinstrap'),
#             (  'Male', 'Torgersen',    'Adelie'),
#             ('Female',    'Biscoe',    'Adelie'),
#             ('Female',    'Biscoe',    'Gentoo'),
#             ('Female',     'Dream',    'Adelie'),
#             ('Female',     'Dream', 'Chinstrap'),
#             ('Female', 'Torgersen',    'Adelie')],
#            names=[None, 'island', 'species'])

# %%
result.index[0][1]
# Out:
# 'Biscoe'

# %% [markdown]
# ## Penguin Pop Breakdown per Island

# %%
m_island_pops
# Out:
# island
# Biscoe       83
# Dream        62
# Torgersen    23
# Name: sex, dtype: int64

# %%
f_island_pops
# Out:
# island
# Biscoe       80
# Dream        61
# Torgersen    24
# Name: sex, dtype: int64

# %%
total_pops
# Out:
#            sex_x  sex_y  island_pop  female_pop_percentage  \
# island
# Biscoe        80     83         163              49.079755
# Dream         61     62         123              49.593496
# Torgersen     24     23          47              51.063830
#
#            males_pop_percentage
# island
# Biscoe                50.920245
# Dream                 50.406504
# Torgersen             48.936170

# %%
total_pops.island_pop.sum()
# Out:
# 333

# %%
total_pops['island_percent'] = (total_pops['island_pop']/total_pops.island_pop.sum())*100
total_pops
# Out:
#            sex_x  sex_y  island_pop  female_pop_percentage  \
# island
# Biscoe        80     83         163              49.079755
# Dream         61     62         123              49.593496
# Torgersen     24     23          47              51.063830
#
#            males_pop_percentage  island_percent
# island
# Biscoe                50.920245       48.948949
# Dream                 50.406504       36.936937
# Torgersen             48.936170       14.114114

# %%
biscoe_percent = round(total_pops.island_percent['Biscoe'], 2)
biscoe_percent
# Out:
# 48.95

# %%
dream_percent = round(total_pops.island_percent['Dream'], 2)
dream_percent
# Out:
# 36.94

# %%
torgersen_percent = round(total_pops.island_percent['Torgersen'], 2)
torgersen_percent
# Out:
# 14.11

# %%
labels = 'Biscoe', 'Dream', 'Torgersen'

# %%
sizes = [biscoe_percent, dream_percent, torgersen_percent]

# %%
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('Penguin Population per Island')
# Out:
# Text(0.5, 1.0, 'Penguin Population per Island')

# %% [markdown]
# ## Tips for comparing islands
# Don't group together Islands AND sex, instead group only by Island
#
# That way, you can add 'Sex' as a hue, and start getting multiple bars and stacks

# %%
penguins = penguins.dropna(axis=0)
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
island_group = penguins.groupby('island')
island_group.mean().head()
# Out:
#            bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# island
# Biscoe          45.248466      15.907362         209.558282  4719.171779
# Dream           44.221951      18.339837         193.186992  3718.902439
# Torgersen       39.038298      18.451064         191.531915  3708.510638

# %%
island_group.head()
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 20  Adelie     Biscoe            37.8           18.3              174.0
# 21  Adelie     Biscoe            37.7           18.7              180.0
# 22  Adelie     Biscoe            35.9           19.2              189.0
# 23  Adelie     Biscoe            38.2           18.1              185.0
# 24  Adelie     Biscoe            38.8           17.2              180.0
# 30  Adelie      Dream            39.5           16.7              178.0
# 31  Adelie      Dream            37.2           18.1              178.0
# ...

# %%
# Based on the above data alone, we can plot:
# Heaviest penguins per island (and also per species?)
# Average bill or flipper properties per island (also per species?)

# %%
# need to group by island or species, try adding a column chart for mass

# %%
# Mean penguin mass per island
sns.catplot(x=island_group.mean().index, y='body_mass_g', data=island_group.mean(), kind='bar')
plt.title('Mean Penguin Mass per Island')
plt.xlabel('Island')
plt.ylabel('Body Mass (g)')
# Out:
# Text(-2.700000000000003, 0.5, 'Body Mass (g)')

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.barplot(x='species', y='body_mass_g', hue='sex', data=penguins, palette="cool")
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x='island', y='body_mass_g', hue='sex', data=penguins, palette = "Blues")
# Out:
# <AxesSubplot:xlabel='island', ylabel='body_mass_g'>
